# %%
# import numpy as np
import pandas as pd 
# import re
# import matplotlib.pyplot as plt
# from textblob import TextBlob

# %%
import json
data = []
with open('../data/stocktwits_messages_2020_01', errors='ignore') as f:
    for line in f:
        data.append(json.loads(line))

# %%
data
# Out:
# [{'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613300,
#    'body': '@liljim2314 how is it going?😂',
#    'created_at': '2020-01-01T00:00:00Z',
#    'user': {'id': 1510885,
#     'username': 'max_0512',
#     'name': 'max',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-06-03',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1,
#     'following': 1,
#     'ideas': 24,
#     'watchlist_stocks_count': 40,
#     'like_count': 130,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 1,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188433116,
#     'in_reply_to_message_id': 188433116,
#     'parent': False,
#     'replies': 4},
#    'mentioned_users': ['@liljim2314'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:00Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613301,
#    'body': 'During the recent years, $CONN&#39;s CEO bought shares at market price  2 times. Six months after the last purchase, the stock was up by +18.71%. Visit https://www.ceo-buys.com to learn more.',
#    'created_at': '2020-01-01T00:00:00Z',
#    'user': {'id': 1719889,
#     'username': 'CEOBuys',
#     'name': 'CEO-Buys.com',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1719889/thumb-1543282592.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1719889/thumb-1543282592.png',
#     'join_date': '2018-11-19',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1316,
#     'following': 0,
#     'ideas': 33206,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 141,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': ['Equities'],
#      'approach': 'Momentum',
#      'holding_period': 'Swing Trader',
#      'experience': 'Professional'}},
#    'source': {'id': 4467,
#     'title': 'CEO Buys',
#     'url': 'https://www.ceo-buys.com'},
#    'symbols': [{'id': 1396,
#      'symbol': 'CONN',
#      'title': 'Conns Inc.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 2181,
#      'exchange': 'NASDAQ',
#      'sector': 'Services',
#      'industry': 'Electronics Stores',
#      'logo_url': 'http://logos.xignite.com/NASDAQGS/00053661.gif',
#      'trending': False,
#      'trending_score': 0.617029}],
#    'prices': [{'id': 1396, 'symbol': 'CONN', 'price': '12.31'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.9239}},
#   'time': '2020-01-01T00:00:00Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613302,
#    'body': '@instravester Thanks man, that really means a lot to me.',
#    'created_at': '2020-01-01T00:00:01Z',
#    'user': {'id': 1471683,
#     'username': 'RodRosenstein',
#     'name': 'RodRosenstein',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1471683/thumb-1559060320.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1471683/thumb-1559060320.png',
#     'join_date': '2018-04-14',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 301,
#     'following': 27,
#     'ideas': 17218,
#     'watchlist_stocks_count': 31,
#     'like_count': 6094,
#     'plus_tier': 'month',
#     'premium_room': '',
#     'subscribers_count': 46,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': 'I’m generally bearish on small-cap biotech—specifically the ones that are super cash-poor. I rarely have a position and I don’t short stocks. Most important: I don’t think I’m smarter than people who do this for a living. You’re not either. 😘',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188610849,
#     'in_reply_to_message_id': 188613114,
#     'parent': False,
#     'replies': 7},
#    'mentioned_users': ['@instravester'],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:01Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613303,
#    'body': '@Tymoto253 nope.',
#    'created_at': '2020-01-01T00:00:01Z',
#    'user': {'id': 1147989,
#     'username': 'Wolfmeister',
#     'name': 'Michael Felker',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1147989/thumb-1501947164.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1147989/thumb-1501947164.png',
#     'join_date': '2017-08-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 6,
#     'following': 64,
#     'ideas': 393,
#     'watchlist_stocks_count': 65,
#     'like_count': 305,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 1,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': 'Florida',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': ['Equities'],
#      'approach': 'Technical',
#      'holding_period': 'Day Trader',
#      'experience': 'Novice'}},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188613245,
#     'in_reply_to_message_id': 188613245,
#     'parent': False,
#     'replies': 1},
#    'mentioned_users': ['@Tymoto253'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:01Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613306,
#    'body': '$BA Buy with both fists.',
#    'created_at': '2020-01-01T00:00:03Z',
#    'user': {'id': 2010156,
#     'username': 'Midengine',
#     'name': 'Martin',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2010156/thumb-1577346506.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2010156/thumb-1577346506.png',
#     'join_date': '2019-04-14',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 4,
#     'following': 2,
#     'ideas': 472,
#     'watchlist_stocks_count': 1,
#     'like_count': 128,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 4437,
#      'symbol': 'BA',
#      'title': 'Boeing Co.',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 52835,
#      'exchange': 'NYSE',
#      'sector': 'Industrial Goods',
#      'industry': 'Aerospace/Defense Products & Services',
#      'logo_url': 'http://logos.xignite.com/NYSE/00000231.gif',
#      'trending': False,
#      'trending_score': -0.60999}],
#    'prices': [{'id': 4437, 'symbol': 'BA', 'price': '325.44'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.7814}},
#   'time': '2020-01-01T00:00:03Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613304,
#    'body': '$SLV - Monthly performance of the algo based option alerts posted for SLV \n https://sleekoptions.com/pps.aspx?sym=SLV',
#    'created_at': '2020-01-01T00:00:02Z',
#    'user': {'id': 2817327,
#     'username': 'sleek_nke',
#     'name': 'sleek_nke',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2817327/thumb-1568866559.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2817327/thumb-1568866559.png',
#     'join_date': '2019-09-19',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 244,
#     'following': 0,
#     'ideas': 34674,
#     'watchlist_stocks_count': 1,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 23,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': 'Post NKE related algo alert updates generated by sleekoptions.com',
#     'website_url': 'https://www.sleekoptions.com/sleekscan.aspx?sub1=pmkt',
#     'trading_strategy': {'assets_frequently_traded': ['Options'],
#      'approach': 'Technical',
#      'holding_period': 'Swing Trader',
#      'experience': 'Intermediate'}},
#    'source': {'id': 4975,
#     'title': 'sleek_nke',
#     'url': 'https://www.sleekoptions.com/opthome.aspx'},
#    'symbols': [{'id': 7233,
#      'symbol': 'SLV',
#      'title': 'iShares Silver Trust',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 14369,
#      'exchange': 'NYSEArca',
#      'sector': 'Financial',
#      'industry': 'Exchange Traded Fund',
#      'logo_url': 'http://logos.xignite.com/AMEX/ishares.gif',
#      'trending': False,
#      'trending_score': 3.30332}],
#    'prices': [{'id': 7233, 'symbol': 'SLV', 'price': '16.67'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:02Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613308,
#    'body': 'old/new whatever.',
#    'created_at': '2020-01-01T00:00:03Z',
#    'user': {'id': 1557843,
#     'username': 'Big_is_Better',
#     'name': 'Sam',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1557843/thumb-1532714908.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1557843/thumb-1532714908.png',
#     'join_date': '2018-07-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 46,
#     'following': 5,
#     'ideas': 4440,
#     'watchlist_stocks_count': 1,
#     'like_count': 4249,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 3,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188613273,
#     'in_reply_to_message_id': 188613273,
#     'parent': False,
#     'replies': 1},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:03Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613307,
#    'body': 'Or they started drinking early',
#    'created_at': '2020-01-01T00:00:03Z',
#    'user': {'id': 1666370,
#     'username': 'LamboSoon',
#     'name': 'Zachary',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1666370/thumb-1562442331.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1666370/thumb-1562442331.png',
#     'join_date': '2018-10-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 18,
#     'following': 2,
#     'ideas': 1844,
#     'watchlist_stocks_count': 1,
#     'like_count': 1311,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 1,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': 'Nevada',
#     'bio': 'Wealthy and lucky',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'reshare_message': {'reshared_count': 1,
#     'reshared_deleted': False,
#     'reshared_user_deleted': False,
#     'parent_reshared_deleted': False,
#     'message': {'id': 188578470,
#      'body': '@Yfin42 could just be everyone is in a buy mood for the new year',
#      'created_at': '2019-12-31T19:11:52Z',
#      'user': {'id': 2088592,
#       'username': 'oneshotstevie',
#       'name': 'Stephen',
#       'avatar_url': 'https://avatars.stocktwits.com/production/2088592/thumb-1573850386.png',
#       'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2088592/thumb-1573850386.png',
#       'join_date': '2019-05-17',
#       'official': False,
#       'identity': 'User',
#       'classification': [],
#       'followers': 32,
#       'following': 11,
#       'ideas': 900,
#       'watchlist_stocks_count': 41,
#       'like_count': 614,
#       'plus_tier': '',
#       'premium_room': '',
#       'subscribers_count': 3,
#       'subscribed_to_count': 0,
#       'following_stocks': 0,
#       'location': None,
#       'bio': None,
#       'website_url': None,
#       'trading_strategy': {'assets_frequently_traded': [],
#        'approach': None,
#        'holding_period': None,
#        'experience': None}},
#      'source': {'id': 2095,
#       'title': 'StockTwits For Android ',
#       'url': 'http://www.stocktwits.com/mobile'},
#      'conversation': {'parent_message_id': 188577475,
#       'in_reply_to_message_id': 188577475,
#       'parent': False,
#       'replies': 2},
#      'mentioned_users': ['@Yfin42'],
#      'entities': {'sentiment': {'basic': 'Bullish'}}}},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:03Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613310,
#    'body': '@RxTek 🤣😂',
#    'created_at': '2020-01-01T00:00:04Z',
#    'user': {'id': 1962340,
#     'username': 'Handsom',
#     'name': 'Eric',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1962340/thumb-1553503429.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1962340/thumb-1553503429.png',
#     'join_date': '2019-03-25',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 323,
#     'following': 150,
#     'ideas': 8581,
#     'watchlist_stocks_count': 88,
#     'like_count': 11076,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 29,
#     'subscribed_to_count': 17,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188607531,
#     'in_reply_to_message_id': 188607531,
#     'parent': False,
#     'replies': 2},
#    'mentioned_users': ['@RxTek'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:04Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613312,
#    'body': '$ACB yesterday’s drop was to trap the $2 put buyers out of their shares',
#    'created_at': '2020-01-01T00:00:04Z',
#    'user': {'id': 1202830,
#     'username': 'dtv650',
#     'name': 'Danny V',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2017-09-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 10,
#     'following': 3,
#     'ideas': 3084,
#     'watchlist_stocks_count': 11,
#     'like_count': 400,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 1,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 15005,
#      'symbol': 'ACB',
#      'title': 'Aurora Cannabis Inc',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 56455,
#      'exchange': 'NYSE',
#      'sector': None,
#      'industry': None,
#      'logo_url': None,
#      'trending': False,
#      'trending_score': 8.60902}],
#    'prices': [{'id': 15005, 'symbol': 'ACB', 'price': '2.15'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.4729}},
#   'time': '2020-01-01T00:00:04Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613305,
#    'body': '6. Baseline was at 74 min/day , In the NOpulse® arm there is no improvement (around 2 min improvement at month 3) and very much at baseline level at Month 4 but placebo group had around -15min/day decrease so because of that study met primary efficacy endpoint. 7. it took almost 1 year to recruit 40 patients (Cohort 1- 40 patients 1 yr &amp; cohort 2- 40 patients 1 year) and they are trying to recruit at least 300 in Phase 3 study so it takes at least 2 years to complete the enrollment. 8. IMO, SP will increase once R/S is done and they announce recruitment of 1st patient in P3 study end of March. 9. Chance of phase 3 success is less.',
#    'created_at': '2020-01-01T00:00:02Z',
#    'user': {'id': 1730609,
#     'username': 'pharma_investor',
#     'name': 'pharmainvestor',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-11-25',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 41,
#     'following': 2,
#     'ideas': 161,
#     'watchlist_stocks_count': 57,
#     'like_count': 91,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 2,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188613223,
#     'in_reply_to_message_id': 188613223,
#     'parent': False,
#     'replies': 1},
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_188613305.PNG',
#      'large': 'https://charts.stocktwits.com/production/large_188613305.PNG',
#      'original': 'https://charts.stocktwits.com/production/original_188613305.PNG',
#      'url': 'https://charts.stocktwits.com/production/original_188613305.PNG'},
#     'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0743}},
#   'time': '2020-01-01T00:00:02Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613309,
#    'body': '@Tymoto253 Nope Holiday',
#    'created_at': '2020-01-01T00:00:03Z',
#    'user': {'id': 782841,
#     'username': 'TxAg02',
#     'name': 'Robert',
#     'avatar_url': 'https://avatars.stocktwits.com/production/782841/thumb-1471181222.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/782841/thumb-1471181222.png',
#     'join_date': '2016-06-27',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 41,
#     'following': 239,
#     'ideas': 475,
#     'watchlist_stocks_count': 283,
#     'like_count': 548,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 1,
#     'subscribed_to_count': 127,
#     'following_stocks': 0,
#     'location': 'Houston',
#     'bio': 'Engineer in Fortune 200 Oil Services company. Swing trade using TA and setups. Continually learning from trades. Always take and secure profit when present, minimize risk, and assess with DD.',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188613245,
#     'in_reply_to_message_id': 188613245,
#     'parent': False,
#     'replies': 2},
#    'mentioned_users': ['@Tymoto253'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:03Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613299,
#    'body': '$MNK has a bad technical rating, but it does show a decent setup pattern. https://www.chartmill.com/stock/quote/MNK/technical-analysis?key=d857317a-d94c-4373-adc3-9cbe67b2f3fb&amp;utm_source=stocktwits&amp;utm_medium=TA&amp;utm_content=MNK&amp;utm_campaign=social_tracking',
#    'created_at': '2020-01-01T00:00:00Z',
#    'user': {'id': 47688,
#     'username': 'ChartMill',
#     'name': 'ChartMill',
#     'avatar_url': 'https://avatars.stocktwits.com/production/47688/thumb-1363343728.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/47688/thumb-1363343728.png',
#     'join_date': '2011-01-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 13045,
#     'following': 899,
#     'ideas': 749031,
#     'watchlist_stocks_count': 20,
#     'like_count': 32,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 658,
#     'subscribed_to_count': 0,
#     'following_stocks': 1,
#     'location': 'Belgium',
#     'bio': 'Chartmill.com, the number 1 technical stock screener incl. VWAP, Relative strength and a lot more! Additional tools are added on a regular basis. Made by real traders, used by real traders!',
#     'website_url': 'http://www.chartmill.com',
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': 'Technical',
#      'holding_period': 'Swing Trader',
#      'experience': 'Professional'}},
#    'source': {'id': 1135,
#     'title': 'ChartMill',
#     'url': 'http://www.chartmill.com'},
#    'symbols': [{'id': 11876,
#      'symbol': 'MNK',
#      'title': 'Mallinckrodt plc',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 6383,
#      'exchange': 'NYSE',
#      'sector': None,
#      'industry': None,
#      'logo_url': 'http://logos.xignite.com/NYSE/00078689.gif',
#      'trending': False,
#      'trending_score': 1.04046}],
#    'prices': [{'id': 11876, 'symbol': 'MNK', 'price': '3.50'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:00Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613311,
#    'body': 'Brown-forman $BF.B Trading Report http://tinyurl.com/syz3sn9',
#    'created_at': '2020-01-01T00:00:04Z',
#    'user': {'id': 456768,
#     'username': 'stocktradersdaily',
#     'name': 'Stock Traders Daily',
#     'avatar_url': 'https://avatars.stocktwits.com/production/456768/thumb-1422538105.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/456768/thumb-1422538105.png',
#     'join_date': '2015-01-29',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 237,
#     'following': 0,
#     'ideas': 27168,
#     'watchlist_stocks_count': 0,
#     'like_count': 0,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 20,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': 'La Jolla, CA',
#     'bio': 'Offering Strategies, Indicators, and Macroeconomic Analysis since 2000. www.stocktradersdaily.com',
#     'website_url': 'https://members.stocktradersdaily.com/seo/freetrial2.php?vendor=80',
#     'trading_strategy': {'assets_frequently_traded': ['Equities'],
#      'approach': 'Technical',
#      'holding_period': 'Swing Trader',
#      'experience': 'Professional'}},
#    'source': {'id': 4326,
#     'title': 'Stock Traders Daily',
#     'url': 'https://www.stocktradersdaily.com'},
#    'symbols': [{'id': 4485,
#      'symbol': 'BF.B',
#      'title': 'Brown-Forman Corporation',
#      'aliases': ['BFB'],
#      'is_following': False,
#      'watchlist_count': 571,
#      'exchange': 'NYSE',
#      'sector': 'Consumer Goods',
#      'industry': 'Beverages - Wineries & Distillers',
#      'logo_url': 'http://logos.xignite.com/NYSE/00002249.gif',
#      'trending': False,
#      'trending_score': 0.0}],
#    'prices': [{'id': 4485, 'symbol': 'BF-B', 'price': '67.60'}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_188613311.png',
#      'large': 'https://charts.stocktwits.com/production/large_188613311.png',
#      'original': 'https://charts.stocktwits.com/production/original_188613311.png',
#      'url': 'https://charts.stocktwits.com/production/original_188613311.png'},
#     'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:04Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613313,
#    'body': '@BringItOnNow Jan/feb will be strong',
#    'created_at': '2020-01-01T00:00:05Z',
#    'user': {'id': 1734908,
#     'username': 'Random_shareholder',
#     'name': 'Random_shareholder',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1734908/thumb-1543420340.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1734908/thumb-1543420340.png',
#     'join_date': '2018-11-28',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8,
#     'following': 1,
#     'ideas': 634,
#     'watchlist_stocks_count': 13,
#     'like_count': 258,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188603614,
#     'in_reply_to_message_id': 188612860,
#     'parent': False,
#     'replies': 8},
#    'mentioned_users': ['@BringItOnNow'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.7663}},
#   'time': '2020-01-01T00:00:05Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613314,
#    'body': '$CGC  Step 5 Block clueless bears.',
#    'created_at': '2020-01-01T00:00:05Z',
#    'user': {'id': 1969274,
#     'username': 'BudWiser007',
#     'name': 'BudWiser007',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1969274/thumb-1553705634.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1969274/thumb-1553705634.png',
#     'join_date': '2019-03-27',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 9,
#     'following': 3,
#     'ideas': 631,
#     'watchlist_stocks_count': 55,
#     'like_count': 862,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 1,
#     'following_stocks': 0,
#     'location': '',
#     'bio': '“He who controls the spice controls the universe.”',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 8260,
#      'symbol': 'CGC',
#      'title': 'Canopy Growth Corporation ',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 50562,
#      'exchange': 'NYSE',
#      'sector': 'Basic Materials',
#      'industry': 'Gold',
#      'logo_url': 'http://logos.xignite.com/AMEX/00043329.gif',
#      'trending': True,
#      'trending_score': 7.89656}],
#    'prices': [{'id': 8260, 'symbol': 'CGC', 'price': '21.09'}],
#    'reshare_message': {'reshared_count': 1,
#     'reshared_deleted': False,
#     'reshared_user_deleted': False,
#     'parent_reshared_deleted': False,
#     'message': {'id': 188608390,
#      'body': '$CGC dip to ~$20.25 thursday. \n\nStep 1 open 4 hour chart \nStep 2 draw pricelevel at todays high\nStep 3 notice it touch and/or penetrate said level on 11/8 11/21 12/9 and 12/13 \nStep 4 notice the following candles were red in all 4 instances. \n(Volume was substantially higher on 11/21 and it still gave the gains right back the following day) \n\nOpened bearish weeklys before close',
#      'created_at': '2019-12-31T22:43:08Z',
#      'user': {'id': 553285,
#       'username': 'aganf',
#       'name': 'Agan F',
#       'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#       'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#       'join_date': '2015-07-20',
#       'official': False,
#       'identity': 'User',
#       'classification': [],
#       'followers': 8,
#       'following': 80,
#       'ideas': 154,
#       'watchlist_stocks_count': 71,
#       'like_count': 305,
#       'plus_tier': '',
#       'premium_room': '',
#       'subscribers_count': 0,
#       'subscribed_to_count': 6,
#       'following_stocks': 0,
#       'location': None,
#       'bio': None,
#       'website_url': None,
#       'trading_strategy': {'assets_frequently_traded': [],
#        'approach': None,
#        'holding_period': None,
#        'experience': None}},
#      'source': {'id': 1149,
#       'title': 'StockTwits for iOS',
#       'url': 'http://www.stocktwits.com/mobile'},
#      'symbols': [{'id': 8260,
#        'symbol': 'CGC',
#        'title': 'Canopy Growth Corporation ',
#        'aliases': [],
#        'is_following': False,
#        'watchlist_count': 50562,
#        'exchange': 'NYSE',
#        'sector': 'Basic Materials',
#        'industry': 'Gold',
#        'logo_url': 'http://logos.xignite.com/AMEX/00043329.gif',
#        'trending': True,
#        'trending_score': 7.89656}],
#      'prices': [{'id': 8260, 'symbol': 'CGC', 'price': '21.05'}],
#      'mentioned_users': [],
#      'entities': {'sentiment': {'basic': 'Bearish'}}}},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': -0.812}},
#   'time': '2020-01-01T00:00:05Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613315,
#    'body': '@stockchatz @furloco you speak of what you don’t know.  MD Anderson doesn’t accept bogus cancer research firms.',
#    'created_at': '2020-01-01T00:00:06Z',
#    'user': {'id': 1422073,
#     'username': 'Robn1020',
#     'name': 'Rob New',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1422073/thumb-1522263018.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1422073/thumb-1522263018.png',
#     'join_date': '2018-02-24',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 5,
#     'following': 4,
#     'ideas': 837,
#     'watchlist_stocks_count': 5,
#     'like_count': 182,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 1,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188588092,
#     'in_reply_to_message_id': 188588218,
#     'parent': False,
#     'replies': 8},
#    'mentioned_users': ['@stockchatz', '@furloco'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:06Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613316,
#    'body': '@jackieM00n You need to grow up. you change from bullish to bearish everyday lol',
#    'created_at': '2020-01-01T00:00:07Z',
#    'user': {'id': 2997117,
#     'username': 'MorganJJ99',
#     'name': 'John',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2019-12-31',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 0,
#     'following': 0,
#     'ideas': 45,
#     'watchlist_stocks_count': 2,
#     'like_count': 13,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188611781,
#     'in_reply_to_message_id': 188611781,
#     'parent': False,
#     'replies': 3},
#    'mentioned_users': ['@jackieM00n'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': -0.445}},
#   'time': '2020-01-01T00:00:07Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613317,
#    'body': '@Stankyb3b3 isn’t that when you sel your washer?',
#    'created_at': '2020-01-01T00:00:09Z',
#    'user': {'id': 2266394,
#     'username': 'chocolatethunder47',
#     'name': 'Joe Mama',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2266394/thumb-1571709293.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2266394/thumb-1571709293.png',
#     'join_date': '2019-08-20',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 31,
#     'following': 29,
#     'ideas': 3205,
#     'watchlist_stocks_count': 48,
#     'like_count': 2264,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 2,
#     'subscribed_to_count': 2,
#     'following_stocks': 0,
#     'location': '',
#     'bio': 'BTD has never not worked. Future assistant to @neotrades 🏄',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188612193,
#     'in_reply_to_message_id': 188612193,
#     'parent': False,
#     'replies': 4},
#    'mentioned_users': ['@Stankyb3b3'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:09Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613318,
#    'body': '@Mr_CirculatorTwits \n\nIs good also for the village @SmurfVillage \n🍄',
#    'created_at': '2020-01-01T00:00:09Z',
#    'user': {'id': 1469713,
#     'username': 'BWIZE_Twits',
#     'name': 'Bwize',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1469713/thumb-1561071964.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1469713/thumb-1561071964.png',
#     'join_date': '2018-04-12',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 972,
#     'following': 269,
#     'ideas': 34748,
#     'watchlist_stocks_count': 297,
#     'like_count': 25739,
#     'plus_tier': 'life',
#     'premium_room': '',
#     'subscribers_count': 136,
#     'subscribed_to_count': 7,
#     'following_stocks': 0,
#     'location': 'Houston  TX ',
#     'bio': 'Houston TX',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188608869,
#     'in_reply_to_message_id': 188613214,
#     'parent': False,
#     'replies': 5},
#    'mentioned_users': ['@Mr_CirculatorTwits', '@SmurfVillage'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:09Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613319,
#    'body': '$UGAZ happy new year to you all !!! \n\nI’ve turned the fireplace on to help bulls in any way it can ..!!!',
#    'created_at': '2020-01-01T00:00:09Z',
#    'user': {'id': 482569,
#     'username': 'amitDBA',
#     'name': 'Amitabh Bachchan',
#     'avatar_url': 'https://avatars.stocktwits.com/production/482569/thumb-1556887933.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/482569/thumb-1556887933.png',
#     'join_date': '2015-03-10',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 101,
#     'following': 1,
#     'ideas': 2590,
#     'watchlist_stocks_count': 21,
#     'like_count': 528,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 19,
#     'subscribed_to_count': 0,
#     'following_stocks': 8,
#     'location': '',
#     'bio': 'IT professional - studied technical analysis in my free time and try to use that knowledge to make few extra cents. All ideas are my opinions.',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 11269,
#      'symbol': 'UGAZ',
#      'title': 'VelocityShares 3x Long Natural Gas ETN',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 46208,
#      'exchange': 'NYSEArca',
#      'sector': 'Financial',
#      'industry': 'Exchange Traded Fund',
#      'logo_url': None,
#      'trending': False,
#      'trending_score': -4.68989}],
#    'prices': [{'id': 11269, 'symbol': 'UGAZ', 'price': '73.05'}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_188613319.png',
#      'large': 'https://charts.stocktwits.com/production/large_188613319.png',
#      'original': 'https://charts.stocktwits.com/production/original_188613319.png',
#      'url': 'https://charts.stocktwits.com/production/original_188613319.png'},
#     'sentiment': None},
#    'sentiment': {'sentiment_score': 0.817}},
#   'time': '2020-01-01T00:00:09Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613321,
#    'body': '@ExpertFellow Netflix',
#    'created_at': '2020-01-01T00:00:11Z',
#    'user': {'id': 2971054,
#     'username': 'ZackBatFack',
#     'name': 'ZackBatFack',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2971054/thumb-1576506426.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2971054/thumb-1576506426.png',
#     'join_date': '2019-12-16',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 0,
#     'following': 0,
#     'ideas': 97,
#     'watchlist_stocks_count': 1,
#     'like_count': 343,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188606902,
#     'in_reply_to_message_id': 188606902,
#     'parent': False,
#     'replies': 2},
#    'mentioned_users': ['@ExpertFellow'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:11Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613320,
#    'body': '@DemGainsTwits @Mr_CirculatorTwits @SecondHandSmoke @Nostockdamus @BWIZE_Twits @shummy @F3int  \n \nHow does it look now?',
#    'created_at': '2020-01-01T00:00:11Z',
#    'user': {'id': 1552943,
#     'username': 'A_fool_and_his_money',
#     'name': 'Are soon parted',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1552943/thumb-1570659873.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1552943/thumb-1570659873.png',
#     'join_date': '2018-07-21',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 320,
#     'following': 15,
#     'ideas': 7923,
#     'watchlist_stocks_count': 37,
#     'like_count': 2343,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 50,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': 'In the office above the Bank ',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': ['Equities',
#       'Options',
#       'Private Companies'],
#      'approach': 'Fundamental',
#      'holding_period': 'Position Trader',
#      'experience': 'Professional'}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188610326,
#     'in_reply_to_message_id': 188611529,
#     'parent': False,
#     'replies': 12},
#    'mentioned_users': ['@DemGainsTwits',
#     '@Mr_CirculatorTwits',
#     '@SecondHandSmoke',
#     '@Nostockdamus',
#     '@BWIZE_Twits',
#     '@shummy',
#     '@F3int'],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_188613320.png',
#      'large': 'https://charts.stocktwits.com/production/large_188613320.png',
#      'original': 'https://charts.stocktwits.com/production/original_188613320.png',
#      'url': 'https://charts.stocktwits.com/production/original_188613320.png'},
#     'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:11Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613322,
#    'body': 'im buying up the april 30.00 calls. if it goes down to cover gap ill just add more.',
#    'created_at': '2020-01-01T00:00:15Z',
#    'user': {'id': 543008,
#     'username': 'Mahi_Mahi',
#     'name': 'M',
#     'avatar_url': 'https://avatars.stocktwits.com/production/543008/thumb-1539812170.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/543008/thumb-1539812170.png',
#     'join_date': '2015-06-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 1512,
#     'following': 247,
#     'ideas': 22009,
#     'watchlist_stocks_count': 13,
#     'like_count': 6293,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 180,
#     'subscribed_to_count': 0,
#     'following_stocks': 1,
#     'location': 'Bonita springs,FL',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': 'Technical',
#      'holding_period': 'Swing Trader',
#      'experience': 'Intermediate'}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.8877}},
#   'time': '2020-01-01T00:00:15Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613323,
#    'body': '@QuickFlip777 @CourtrePOURTER so do any of you know what it is trading at? That site sucks smh',
#    'created_at': '2020-01-01T00:00:17Z',
#    'user': {'id': 2842444,
#     'username': 'Financialsoverhype',
#     'name': 'Zack',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2019-10-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 2,
#     'following': 0,
#     'ideas': 199,
#     'watchlist_stocks_count': 12,
#     'like_count': 50,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': 'Distressed company analyst. Don’t buy trash, buy quality for less.',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188612005,
#     'in_reply_to_message_id': 188612919,
#     'parent': False,
#     'replies': 4},
#    'mentioned_users': ['@QuickFlip777', '@CourtrePOURTER'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:17Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613324,
#    'body': '$EROS gotta love Australia this time of the year happy new years all u .',
#    'created_at': '2020-01-01T00:00:19Z',
#    'user': {'id': 1465241,
#     'username': 'WarrenCoolidge',
#     'name': 'Coolidge',
#     'avatar_url': 'https://avatars.stocktwits.com/production/1465241/thumb-1559919071.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/1465241/thumb-1559919071.png',
#     'join_date': '2018-04-06',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 671,
#     'following': 21,
#     'ideas': 21977,
#     'watchlist_stocks_count': 39,
#     'like_count': 9442,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 92,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': 'NYC',
#     'bio': 'Swing Trader since 1998. Rules: Cold as Ice, Dont love them, just trade them. Opinions are my own idea and should not be treated as recommendations or financial advice.',
#     'website_url': 'https://www.youtube.com/watch?v=SqYUzKfmYRU&amp;list=PLVmi4SSEfzu7k_76_YYThPtOB5k8NXbuB&amp;index=16',
#     'trading_strategy': {'assets_frequently_traded': ['Equities',
#       'Options',
#       'Futures'],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 11650,
#      'symbol': 'EROS',
#      'title': 'Eros International',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 10863,
#      'exchange': 'NYSE',
#      'sector': None,
#      'industry': None,
#      'logo_url': 'http://logos.xignite.com/NYSE/EROS.gif',
#      'trending': False,
#      'trending_score': 1.90913}],
#    'prices': [{'id': 11650, 'symbol': 'EROS', 'price': '3.39'}],
#    'mentioned_users': [],
#    'entities': {'chart': {'thumb': 'https://charts.stocktwits.com/production/small_188613324.jpg',
#      'large': 'https://charts.stocktwits.com/production/large_188613324.jpg',
#      'original': 'https://charts.stocktwits.com/production/original_188613324.jpg',
#      'url': 'https://charts.stocktwits.com/production/original_188613324.jpg'},
#     'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:00:19Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188613325,
#    'body': '@Millennial12345 @JeLaw178 @SchapiraCapital OK so how much Thursday we looking at cause it did close higher than yesterday and is not bad level.\n\nWhat is target?',
#    'created_at': '2020-01-01T00:00:22Z',
#    'user': {'id': 1375276,
#     'username': 'hrthik',
#     'name': 'roger gupta',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-01-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 8,
#     'following': 29,
#     'ideas': 2431,
#     'watchlist_stocks_count': 6,
#     'like_count': 1,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': None,
# ...
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188614179,
#     'in_reply_to_message_id': 188614179,
#     'parent': False,
#     'replies': 4},
#    'mentioned_users': ['@clulelessrookie'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:17:13Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614280,
#    'body': '$OCGN I want to see strong upward stair steps. Let&#39;s see 0.70-0.85 EOW and $1.00 plus the following.',
#    'created_at': '2020-01-01T00:17:13Z',
#    'user': {'id': 1228020,
#     'username': 'BigGirlsDontCry',
#     'name': 'Jason',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2017-10-15',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 15,
#     'following': 64,
#     'ideas': 1630,
#     'watchlist_stocks_count': 23,
#     'like_count': 269,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 4,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2095,
#     'title': 'StockTwits For Android ',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 12351,
#      'symbol': 'OCGN',
#      'title': 'Ocugen',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 25088,
#      'exchange': 'NASDAQ',
#      'sector': None,
#      'industry': None,
#      'logo_url': None,
#      'trending': False,
#      'trending_score': 2.1351}],
#    'prices': [{'id': 12351, 'symbol': 'OCGN', 'price': '0.52'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.9418}},
#   'time': '2020-01-01T00:17:13Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614282,
#    'body': '@GoodNewsBull its a fake market, its 100% controlled, no longer a free market',
#    'created_at': '2020-01-01T00:17:14Z',
#    'user': {'id': 242564,
#     'username': 'LipstickOnAPig',
#     'name': 'flybythenight',
#     'avatar_url': 'https://avatars.stocktwits.com/production/242564/thumb-1520937201.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/242564/thumb-1520937201.png',
#     'join_date': '2013-07-02',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 90,
#     'following': 60,
#     'ideas': 7949,
#     'watchlist_stocks_count': 61,
#     'like_count': 4873,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 4,
#     'subscribed_to_count': 0,
#     'following_stocks': 1,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188604176,
#     'in_reply_to_message_id': 188604176,
#     'parent': False,
#     'replies': 16},
#    'mentioned_users': ['@GoodNewsBull'],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:17:14Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614283,
#    'body': '@OldMcDonald 🇨🇳 you didn&#39;t sell your farm to the Chinese did you',
#    'created_at': '2020-01-01T00:17:15Z',
#    'user': {'id': 2935652,
#     'username': 'Checkmate69',
#     'name': 'David Epley',
#     'avatar_url': 'https://avatars.stocktwits.com/production/2935652/thumb-1577637104.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/2935652/thumb-1577637104.png',
#     'join_date': '2019-11-27',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3,
#     'following': 0,
#     'ideas': 382,
#     'watchlist_stocks_count': 0,
#     'like_count': 492,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188609370,
#     'in_reply_to_message_id': 188609454,
#     'parent': False,
#     'replies': 8},
#    'mentioned_users': ['@OldMcDonald'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.6161}},
#   'time': '2020-01-01T00:17:15Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614284,
#    'body': '@Scarliver fuck off. Get out of here.',
#    'created_at': '2020-01-01T00:17:15Z',
#    'user': {'id': 2242655,
#     'username': 'AWS66',
#     'name': 'Richard',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2019-08-05',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 0,
#     'following': 0,
#     'ideas': 128,
#     'watchlist_stocks_count': 2,
#     'like_count': 29,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188613222,
#     'in_reply_to_message_id': 188613352,
#     'parent': False,
#     'replies': 2},
#    'mentioned_users': ['@Scarliver'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': -0.7633}},
#   'time': '2020-01-01T00:17:15Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614285,
#    'body': '10 is coming.',
#    'created_at': '2020-01-01T00:17:17Z',
#    'user': {'id': 1582010,
#     'username': 'Geepersman',
#     'name': 'geoffrey coates',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-08-20',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 29,
#     'following': 3,
#     'ideas': 6381,
#     'watchlist_stocks_count': 1,
#     'like_count': 396,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 2,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188612212,
#     'in_reply_to_message_id': 188612212,
#     'parent': False,
#     'replies': 1},
#    'mentioned_users': [],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:17:17Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614286,
#    'body': '@sosa37 @AceGambit seems like the Chinese government is shifting from subsidies incentives to foreign partnership incentives:\n\n“When Beijing reduced EV incentives in June, it appeared that it was softening its zero-emission goals. But we now see that it was changing its strategies by putting a greater burden on automakers, especially foreign firms, to either shift to EVs or subsidize the industry-wide transition.”\n\nhttps://electrek.co/2019/12/06/beijing-shifts-from-ev-subsidies-to-setting-quotas-for-automakers/',
#    'created_at': '2020-01-01T00:17:18Z',
#    'user': {'id': 1645645,
#     'username': 'SaiyanInvestor',
#     'name': 'C R',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2018-10-04',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 32,
#     'following': 1,
#     'ideas': 1119,
#     'watchlist_stocks_count': 13,
#     'like_count': 628,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 6,
#     'subscribed_to_count': 1,
#     'following_stocks': 0,
#     'location': '',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 188604485,
#     'in_reply_to_message_id': 188605662,
#     'parent': False,
#     'replies': 5},
#    'mentioned_users': ['@sosa37', '@AceGambit'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:17:18Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614287,
#    'body': '$CHK Chesapeake energy swings higher in after hours trading with a huge huge API report inventory draw on crude oil',
#    'created_at': '2020-01-01T00:17:19Z',
#    'user': {'id': 2103934,
#     'username': 'gassdrill',
#     'name': 'ness',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2019-05-26',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 26,
#     'following': 66,
#     'ideas': 1766,
#     'watchlist_stocks_count': 12,
#     'like_count': 1578,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 19,
#     'following_stocks': 0,
#     'location': '',
#     'bio': 'Anything I say or text on StockTwits should not be considered investment advice only my own opinion and sense of humor comes from the username gas drill on StockTwits',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'symbols': [{'id': 4723,
#      'symbol': 'CHK',
#      'title': 'Chesapeake Energy Corporation',
#      'aliases': [],
#      'is_following': False,
#      'watchlist_count': 56256,
#      'exchange': 'NYSE',
#      'sector': 'Basic Materials',
#      'industry': 'Independent Oil & Gas',
#      'logo_url': 'http://logos.xignite.com/NYSE/00030225.gif',
#      'trending': False,
#      'trending_score': -1.62571}],
#    'prices': [{'id': 4723, 'symbol': 'CHK', 'price': '0.82'}],
#    'mentioned_users': [],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:17:19Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614288,
#    'body': '@HolyGrailTrading So unhinged and bitter for some one who claims to have made a score.. Why all this non requested justification.? Why Gail.. Screams BS Gail !! Sounds like your having a very very bad week..   LOOL FOOL !!',
#    'created_at': '2020-01-01T00:17:22Z',
#    'user': {'id': 2185150,
#     'username': 'bonergee',
#     'name': 'bonergee',
#     'avatar_url': 'http://avatars.stocktwits.com/images/default_avatar_thumb.jpg',
#     'avatar_url_ssl': 'https://s3.amazonaws.com/st-avatars/images/default_avatar_thumb.jpg',
#     'join_date': '2019-07-09',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 3,
#     'following': 0,
#     'ideas': 706,
#     'watchlist_stocks_count': 2,
#     'like_count': 27,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': None,
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188613436,
#     'in_reply_to_message_id': 188613868,
#     'parent': False,
#     'replies': 2},
#    'mentioned_users': ['@HolyGrailTrading'],
#    'entities': {'sentiment': {'basic': 'Bearish'}},
#    'sentiment': {'sentiment_score': 0.8731}},
#   'time': '2020-01-01T00:17:22Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614289,
#    'body': '@stockchatz u must have blown ur trading acct so many times ... shorting in a crazy bull mkt is a classic behavior of a veteran bad trader.',
#    'created_at': '2020-01-01T00:17:23Z',
#    'user': {'id': 307304,
#     'username': '44wall',
#     'name': 'ron',
#     'avatar_url': 'https://avatars.stocktwits.com/production/307304/thumb-1568688153.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/307304/thumb-1568688153.png',
#     'join_date': '2014-01-30',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 6,
#     'following': 4,
#     'ideas': 230,
#     'watchlist_stocks_count': 11,
#     'like_count': 459,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 0,
#     'subscribed_to_count': 0,
#     'following_stocks': 0,
#     'location': 'New York , NY',
#     'bio': 'the trend is your friend until it ends',
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': ['Equities',
#       'Options',
#       'Forex',
#       'Bonds'],
#      'approach': 'Momentum',
#      'holding_period': 'Position Trader',
#      'experience': 'Professional'}},
#    'source': {'id': 1149,
#     'title': 'StockTwits for iOS',
#     'url': 'http://www.stocktwits.com/mobile'},
#    'conversation': {'parent_message_id': 187905499,
#     'in_reply_to_message_id': 188614144,
#     'parent': False,
#     'replies': 3},
#    'mentioned_users': ['@stockchatz'],
#    'entities': {'sentiment': {'basic': 'Bullish'}},
#    'sentiment': {'sentiment_score': -0.492}},
#   'time': '2020-01-01T00:17:23Z'},
#  {'object': 'Message',
#   'action': 'create',
#   'data': {'id': 188614290,
#    'body': '@Quench wasted my money on ontx..might double my position @ .38',
#    'created_at': '2020-01-01T00:17:24Z',
#    'user': {'id': 215539,
#     'username': 'bryankeithc',
#     'name': 'Bryan Coppedge',
#     'avatar_url': 'https://avatars.stocktwits.com/production/215539/thumb-1530807216.png',
#     'avatar_url_ssl': 'https://avatars.stocktwits.com/production/215539/thumb-1530807216.png',
#     'join_date': '2013-02-18',
#     'official': False,
#     'identity': 'User',
#     'classification': [],
#     'followers': 83,
#     'following': 37,
#     'ideas': 13356,
#     'watchlist_stocks_count': 35,
#     'like_count': 166,
#     'plus_tier': '',
#     'premium_room': '',
#     'subscribers_count': 4,
#     'subscribed_to_count': 0,
#     'following_stocks': 3,
#     'location': 'Seattle ',
#     'bio': None,
#     'website_url': None,
#     'trading_strategy': {'assets_frequently_traded': [],
#      'approach': None,
#      'holding_period': None,
#      'experience': None}},
#    'source': {'id': 2269,
#     'title': 'StockTwits Web',
#     'url': 'https://stocktwits.com'},
#    'conversation': {'parent_message_id': 188507339,
#     'in_reply_to_message_id': 188613422,
#     'parent': False,
#     'replies': 7},
#    'mentioned_users': ['@Quench'],
#    'entities': {'sentiment': None},
#    'sentiment': {'sentiment_score': 0.0}},
#   'time': '2020-01-01T00:17:24Z'},
#  ...]

# %%
df = pd.read_json("../data/stocktwits_messages_2020_01")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_json("../data/stocktwits_messages_2020_01")
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/io/json/_json.py:757, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     754     return json_reader
#     756 with json_reader:
# --> 757     return json_reader.read()
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/io/json/_json.py:915, in JsonReader.read(self)
#     913         obj = self._get_object_parser(self._combine_lines(data_lines))
#     914 else:
# --> 915     obj = self._get_object_parser(self.data)
#     916 self.close()
#     917 return obj
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/io/json/_json.py:937, in JsonReader._get_object_parser(self, json)
#     935 obj = None
#     936 if typ == "frame":
# --> 937     obj = FrameParser(json, **kwargs).parse()
#     939 if typ == "series" or obj is None:
#     940     if not isinstance(dtype, bool):
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/io/json/_json.py:1064, in Parser.parse(self)
#    1062     self._parse_numpy()
#    1063 else:
# -> 1064     self._parse_no_numpy()
#    1066 if self.obj is None:
#    1067     return None
#
# File /opt/miniconda3/envs/adc_project/lib/python3.10/site-packages/pandas/io/json/_json.py:1321, in FrameParser._parse_no_numpy(self)
#    1317 orient = self.orient
#    1319 if orient == "columns":
#    1320     self.obj = DataFrame(
# -> 1321         loads(json, precise_float=self.precise_float), dtype=None
#    1322     )
#    1323 elif orient == "split":
#    1324     decoded = {
#    1325         str(k): v
#    1326         for k, v in loads(json, precise_float=self.precise_float).items()
#    1327     }
#
# ValueError: Trailing data

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
from pandarallel import pandarallel

pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
df = pd.read_csv("../data/Tweet.csv")
df.head(10)
# Out:
#              tweet_id           writer   post_date  \
# 0  550441509175443456  VisualStockRSRC  1420070457
# 1  550441672312512512      KeralaGuy77  1420070496
# 2  550441732014223360      DozenStocks  1420070510
# 3  550442977802207232     ShowDreamCar  1420070807
# 4  550443807834402816     i_Know_First  1420071005
# 5  550443808606126081    aaplstocknews  1420071005
# 6  550443809700851716       iknowfirst  1420071005
# 7  550443857142611968      Cprediction  1420071016
# 8  550443857595600896    iknowfirst_br  1420071017
# 9  550443857692078081  Gold_prediction  1420071017
#
#                                                 body  comment_num  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...            0
# 1  Insanity of today weirdo massive selling. $aap...            0
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...            0
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...            0
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...            0
# 5  Swing Trading: Up To 8.91% Return In 14 Days h...            0
# 6  Swing Trading: Up To 8.91% Return In 14 Days h...            0
# 7  Swing Trading: Up To 8.91% Return In 14 Days h...            0
# 8  Swing Trading: Up To 8.91% Return In 14 Days h...            0
# 9  Swing Trading: Up To 8.91% Return In 14 Days h...            0
#
#    retweet_num  like_num
# 0            0         1
# 1            0         0
# 2            0         0
# 3            0         1
# 4            0         1
# 5            0         1
# 6            0         1
# 7            0         1
# 8            0         1
# 9            0         1

# %%
len(df)
# Out:
# 3717964

# %%
df = df[["body"]]
df.columns = ["tweets"]

# %%
df
# Out:
#                                                     tweets
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...
# 1        Insanity of today weirdo massive selling. $aap...
# 2        S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3        $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4        Swing Trading: Up To 8.91% Return In 14 Days h...
# ...                                                    ...
# 3717959  That $SPY $SPX puuump in the last hour was the...
# 3717960  In 2020 I may start Tweeting out positive news...
# 3717961  Patiently Waiting for the no twitter sitter tw...
# 3717962  I don't discriminate. I own both $aapl and $ms...
# 3717963  $AAPL #patent 10,522,475 Vertical interconnect...
#
# [3717964 rows x 1 columns]

# %%
# create a function to clean the tweets
def cleanTwt(twt):
    twt = re.sub("#aapl", 'aapl', twt) # removes the '#' from apple
    twt = re.sub("#AAPL", 'AAPL', twt)
    twt = re.sub("#amzn", 'amzn', twt) # removes the '#' from amazon
    twt = re.sub("#AMZN", 'AMZN', twt)
    twt = re.sub("#googl", 'googl', twt) # removes the '#' from google
    twt = re.sub("#GOOGL", 'GOOGL', twt)
    twt = re.sub("#msft", 'msft', twt) # removes the '#' from microsoft
    twt = re.sub("#MSFT", 'MSFT', twt)
    twt = re.sub("#tsla", 'tsla', twt) # removes the '#' from tesla
    twt = re.sub("#TSLA", 'TSLA', twt)
    twt = re.sub('#[A-Za-z0-9]+', '', twt) # removes any string with a '#'
    twt = re.sub('\\n', '', twt) # removes the '\n' string
    twt = re.sub('https:\/\/\S+', '', twt) # removes any hyperlinks
    return twt

# %%
df["cleaned_tweets"] = df["tweets"].parallel_apply(cleanTwt)
df
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=464746), Label(value='0 / 464746')…
#                                                     tweets  \
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...
# 1        Insanity of today weirdo massive selling. $aap...
# 2        S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3        $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4        Swing Trading: Up To 8.91% Return In 14 Days h...
# ...                                                    ...
# 3717959  That $SPY $SPX puuump in the last hour was the...
# 3717960  In 2020 I may start Tweeting out positive news...
# 3717961  Patiently Waiting for the no twitter sitter tw...
# 3717962  I don't discriminate. I own both $aapl and $ms...
# 3717963  $AAPL #patent 10,522,475 Vertical interconnect...
#
#                                             cleaned_tweets
# 0        lx21 made $10,008  on $AAPL -Check it out! htt...
# 1        Insanity of today weirdo massive selling. $aap...
# 2        S&P100  Performance $HD $LOW $SBUX $TGT $DVN $...
# 3        $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4        Swing Trading: Up To 8.91% Return In 14 Days h...
# ...                                                    ...
# 3717959  That $SPY $SPX puuump in the last hour was the...
# 3717960  In 2020 I may start Tweeting out positive news...
# 3717961  Patiently Waiting for the no twitter sitter tw...
# 3717962  I don't discriminate. I own both $aapl and $ms...
# 3717963  $AAPL  10,522,475 Vertical interconnects for s...
#
# [3717964 rows x 2 columns]

# %%
# create a function to get subjectivity
def getSubjectivity(twt):
    return TextBlob(twt).sentiment.subjectivity

# create a function to get the polarity
def getPolarity(twt):
    return TextBlob(twt).sentiment.polarity

# create two new columns called "Subjectivity" & "Polarity"
df['subjectivity'] = df['cleaned_tweets'].parallel_apply(getSubjectivity)
df['polarity'] = df['cleaned_tweets'].parallel_apply(getPolarity)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=464746), Label(value='0 / 464746')…
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=464746), Label(value='0 / 464746')…

# %%
df.head(5)
# Out:
#                                               tweets  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...
# 1  Insanity of today weirdo massive selling. $aap...
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...
#
#                                       cleaned_tweets  subjectivity  polarity
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...           0.0      0.00
# 1  Insanity of today weirdo massive selling. $aap...           1.0      0.00
# 2  S&P100  Performance $HD $LOW $SBUX $TGT $DVN $...           0.4      0.25
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...           0.5      0.25
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...           0.0      0.00

# %%
# create a function get the sentiment text
def getSentiment(score):
    if score < 0:
        return "negative"
    elif score == 0:
        return "neutral"
    else:
        return "positive"

# %%
# create a column to store the text sentiment
df['sentiment'] = df['polarity'].parallel_apply(getSentiment)

# show the data
df.head()
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=464746), Label(value='0 / 464746')…
#                                               tweets  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...
# 1  Insanity of today weirdo massive selling. $aap...
# 2  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...
#
#                                       cleaned_tweets  subjectivity  polarity  \
# 0  lx21 made $10,008  on $AAPL -Check it out! htt...           0.0      0.00
# 1  Insanity of today weirdo massive selling. $aap...           1.0      0.00
# 2  S&P100  Performance $HD $LOW $SBUX $TGT $DVN $...           0.4      0.25
# 3  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...           0.5      0.25
# 4  Swing Trading: Up To 8.91% Return In 14 Days h...           0.0      0.00
#
#   sentiment
# 0   neutral
# 1   neutral
# 2  positive
# 3  positive
# 4   neutral

# %%
# create a scatter plot to show the subjectivity and the polarity
plt.figure(figsize=(14,10))

for i in range(0, 2000):
    plt.scatter(df["polarity"].iloc[[i]].values[0], df["subjectivity"].iloc[[i]].values[0], color="Purple")

plt.title("Sentiment Analysis Scatter Plot")
plt.xlabel('polarity')
plt.ylabel('subjectivity')
plt.grid(linestyle="--")
plt.show()

# %%
# create a bar chart to show the cout of Positive, Neutral and Negative sentiments
df['sentiment'].value_counts().plot(kind="bar")
plt.title("Sentiment Analysis Scatter Plot")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.grid(linestyle="--")
plt.show()

# %%
df.to_csv("../data/data_labeled.csv")
